# %%
from nilearn.input_data import NiftiMasker
from nilearn.image import load_img, concat_imgs

import pandas as pd
import numpy as np
import nibabel as nib

import glob
import os
# mask list
masks = []
with open('masklist.txt', 'r', encoding='utf-8') as file:
    # Read and process content line by line
    for idx, line in enumerate(file):
        masks.append(line.strip())

# concatenate all the effect size maps into one nifti file
language = 'CN'
subjects = [36,33,28,4]
runs= [6,7,8,9,10,11,12,13,14]

for subject in subjects:
    
    for run in runs:
        
        img_path = f'1stGLM/sub-{language}{subject:0>3d}/run-{run:0>2d}'
        
        image_list = [load_img(os.path.join(img_path, f)) for f in os.listdir(img_path) if f.endswith('effect_size.nii.gz')]
            
        big_nii = concat_imgs(image_list)
        print('done concatenating images')
        print(big_nii.dataobj.shape)



        betas = []
        for idx, mask in enumerate(masks):
            print(f"Working on {mask}")
                    
            mask_file = f'masks/{mask}.nii.gz'
            
            masker = NiftiMasker(mask_img=mask_file, standardize=False, detrend=False,
                            memory="nilearn_cache", memory_level=2)
            
            beta = masker.fit_transform(big_nii).mean(axis=1)
            print(beta.shape)
            betas.append(beta)

        betas_df = pd.DataFrame(betas).T
        betas_df.columns = [masks]
        betas_df.to_csv(f'1stGLM/sub-{language}{subject:0>3d}/run-{(run-5):0>2d}-GLM_betas.csv', index=False)
# Out:
# done concatenating images
# (46, 56, 48, 143)
# Working on Angular_L
# /home/lyh/anaconda3/envs/llm4brain/lib/python3.10/site-packages/joblib/memory.py:577: JobLibCollisionWarning: Cannot detect name collisions for function 'nifti_masker_extractor'
#   return self._cached_call(args, kwargs, shelving=False)[0]
# (143,)
# Working on Frontal_Inf_Orb_2_L
# (143,)
# Working on Frontal_Inf_Tri_L
# (143,)
# Working on Frontal_Mid_2_L
# (143,)
# Working on Temporal_Pole_Sup_L
# (143,)
# Working on Temporal_Mid_L
# (143,)
# done concatenating images
# (46, 56, 48, 142)
# Working on Angular_L
# /home/lyh/anaconda3/envs/llm4brain/lib/python3.10/site-packages/joblib/memory.py:577: JobLibCollisionWarning: Cannot detect name collisions for function 'nifti_masker_extractor'
#   return self._cached_call(args, kwargs, shelving=False)[0]
# (142,)
# Working on Frontal_Inf_Orb_2_L
# (142,)
# Working on Frontal_Inf_Tri_L
# (142,)
# Working on Frontal_Mid_2_L
# (142,)
# Working on Temporal_Pole_Sup_L
# (142,)
# Working on Temporal_Mid_L
# (142,)
# done concatenating images
# (46, 56, 48, 199)
# Working on Angular_L
# /home/lyh/anaconda3/envs/llm4brain/lib/python3.10/site-packages/joblib/memory.py:577: JobLibCollisionWarning: Cannot detect name collisions for function 'nifti_masker_extractor'
#   return self._cached_call(args, kwargs, shelving=False)[0]
# (199,)
# Working on Frontal_Inf_Orb_2_L
# (199,)
# Working on Frontal_Inf_Tri_L
# (199,)
# Working on Frontal_Mid_2_L
# (199,)
# Working on Temporal_Pole_Sup_L
# (199,)
# Working on Temporal_Mid_L
# (199,)
# done concatenating images
# (46, 56, 48, 159)
# Working on Angular_L
# /home/lyh/anaconda3/envs/llm4brain/lib/python3.10/site-packages/joblib/memory.py:577: JobLibCollisionWarning: Cannot detect name collisions for function 'nifti_masker_extractor'
#   return self._cached_call(args, kwargs, shelving=False)[0]
# (159,)
# Working on Frontal_Inf_Orb_2_L
# (159,)
# Working on Frontal_Inf_Tri_L
# (159,)
# Working on Frontal_Mid_2_L
# (159,)
# Working on Temporal_Pole_Sup_L
# (159,)
# Working on Temporal_Mid_L
# (159,)
# done concatenating images
# (46, 56, 48, 167)
# Working on Angular_L
# /home/lyh/anaconda3/envs/llm4brain/lib/python3.10/site-packages/joblib/memory.py:577: JobLibCollisionWarning: Cannot detect name collisions for function 'nifti_masker_extractor'
#   return self._cached_call(args, kwargs, shelving=False)[0]
# (167,)
# Working on Frontal_Inf_Orb_2_L
# (167,)
# Working on Frontal_Inf_Tri_L
# (167,)
# Working on Frontal_Mid_2_L
# (167,)
# Working on Temporal_Pole_Sup_L
# (167,)
# Working on Temporal_Mid_L
# (167,)
# done concatenating images
# (46, 56, 48, 208)
# Working on Angular_L
# /home/lyh/anaconda3/envs/llm4brain/lib/python3.10/site-packages/joblib/memory.py:577: JobLibCollisionWarning: Cannot detect name collisions for function 'nifti_masker_extractor'
#   return self._cached_call(args, kwargs, shelving=False)[0]
# (208,)
# Working on Frontal_Inf_Orb_2_L
# (208,)
# Working on Frontal_Inf_Tri_L
# (208,)
# Working on Frontal_Mid_2_L
# (208,)
# Working on Temporal_Pole_Sup_L
# (208,)
# Working on Temporal_Mid_L
# (208,)
# done concatenating images
# (46, 56, 48, 198)
# Working on Angular_L
# /home/lyh/anaconda3/envs/llm4brain/lib/python3.10/site-packages/joblib/memory.py:577: JobLibCollisionWarning: Cannot detect name collisions for function 'nifti_masker_extractor'
#   return self._cached_call(args, kwargs, shelving=False)[0]
# (198,)
# Working on Frontal_Inf_Orb_2_L
# (198,)
# Working on Frontal_Inf_Tri_L
# (198,)
# Working on Frontal_Mid_2_L
# (198,)
# Working on Temporal_Pole_Sup_L
# (198,)
# Working on Temporal_Mid_L
# (198,)
# done concatenating images
# (46, 56, 48, 153)
# Working on Angular_L
# /home/lyh/anaconda3/envs/llm4brain/lib/python3.10/site-packages/joblib/memory.py:577: JobLibCollisionWarning: Cannot detect name collisions for function 'nifti_masker_extractor'
#   return self._cached_call(args, kwargs, shelving=False)[0]
# (153,)
# Working on Frontal_Inf_Orb_2_L
# (153,)
# Working on Frontal_Inf_Tri_L
# (153,)
# Working on Frontal_Mid_2_L
# (153,)
# Working on Temporal_Pole_Sup_L
# (153,)
# Working on Temporal_Mid_L
# (153,)
# done concatenating images
# (46, 56, 48, 208)
# Working on Angular_L
# /home/lyh/anaconda3/envs/llm4brain/lib/python3.10/site-packages/joblib/memory.py:577: JobLibCollisionWarning: Cannot detect name collisions for function 'nifti_masker_extractor'
#   return self._cached_call(args, kwargs, shelving=False)[0]
# (208,)
# Working on Frontal_Inf_Orb_2_L
# (208,)
# Working on Frontal_Inf_Tri_L
# (208,)
# Working on Frontal_Mid_2_L
# (208,)
# Working on Temporal_Pole_Sup_L
# (208,)
# Working on Temporal_Mid_L
# (208,)
# done concatenating images
# (46, 56, 48, 143)
# Working on Angular_L
# /home/lyh/anaconda3/envs/llm4brain/lib/python3.10/site-packages/joblib/memory.py:577: JobLibCollisionWarning: Cannot detect name collisions for function 'nifti_masker_extractor'
#   return self._cached_call(args, kwargs, shelving=False)[0]
# (143,)
# Working on Frontal_Inf_Orb_2_L
# (143,)
# Working on Frontal_Inf_Tri_L
# (143,)
# Working on Frontal_Mid_2_L
# (143,)
# Working on Temporal_Pole_Sup_L
# (143,)
# Working on Temporal_Mid_L
# (143,)
# done concatenating images
# (46, 56, 48, 142)
# Working on Angular_L
# /home/lyh/anaconda3/envs/llm4brain/lib/python3.10/site-packages/joblib/memory.py:577: JobLibCollisionWarning: Cannot detect name collisions for function 'nifti_masker_extractor'
#   return self._cached_call(args, kwargs, shelving=False)[0]
# (142,)
# Working on Frontal_Inf_Orb_2_L
# (142,)
# Working on Frontal_Inf_Tri_L
# (142,)
# Working on Frontal_Mid_2_L
# (142,)
# Working on Temporal_Pole_Sup_L
# (142,)
# Working on Temporal_Mid_L
# (142,)
# done concatenating images
# (46, 56, 48, 199)
# Working on Angular_L
# /home/lyh/anaconda3/envs/llm4brain/lib/python3.10/site-packages/joblib/memory.py:577: JobLibCollisionWarning: Cannot detect name collisions for function 'nifti_masker_extractor'
#   return self._cached_call(args, kwargs, shelving=False)[0]
# (199,)
# Working on Frontal_Inf_Orb_2_L
# (199,)
# Working on Frontal_Inf_Tri_L
# (199,)
# Working on Frontal_Mid_2_L
# (199,)
# Working on Temporal_Pole_Sup_L
# (199,)
# Working on Temporal_Mid_L
# (199,)
# done concatenating images
# (46, 56, 48, 159)
# Working on Angular_L
# /home/lyh/anaconda3/envs/llm4brain/lib/python3.10/site-packages/joblib/memory.py:577: JobLibCollisionWarning: Cannot detect name collisions for function 'nifti_masker_extractor'
#   return self._cached_call(args, kwargs, shelving=False)[0]
# (159,)
# Working on Frontal_Inf_Orb_2_L
# (159,)
# Working on Frontal_Inf_Tri_L
# (159,)
# Working on Frontal_Mid_2_L
# (159,)
# Working on Temporal_Pole_Sup_L
# (159,)
# Working on Temporal_Mid_L
# (159,)
# done concatenating images
# (46, 56, 48, 167)
# Working on Angular_L
# /home/lyh/anaconda3/envs/llm4brain/lib/python3.10/site-packages/joblib/memory.py:577: JobLibCollisionWarning: Cannot detect name collisions for function 'nifti_masker_extractor'
#   return self._cached_call(args, kwargs, shelving=False)[0]
# (167,)
# Working on Frontal_Inf_Orb_2_L
# (167,)
# Working on Frontal_Inf_Tri_L
# (167,)
# Working on Frontal_Mid_2_L
# (167,)
# Working on Temporal_Pole_Sup_L
# (167,)
# Working on Temporal_Mid_L
# (167,)
# done concatenating images
# (46, 56, 48, 208)
# Working on Angular_L
# /home/lyh/anaconda3/envs/llm4brain/lib/python3.10/site-packages/joblib/memory.py:577: JobLibCollisionWarning: Cannot detect name collisions for function 'nifti_masker_extractor'
#   return self._cached_call(args, kwargs, shelving=False)[0]
# (208,)
# Working on Frontal_Inf_Orb_2_L
# (208,)
# Working on Frontal_Inf_Tri_L
# (208,)
# Working on Frontal_Mid_2_L
# (208,)
# Working on Temporal_Pole_Sup_L
# (208,)
# Working on Temporal_Mid_L
# (208,)
# done concatenating images
# (46, 56, 48, 198)
# Working on Angular_L
# /home/lyh/anaconda3/envs/llm4brain/lib/python3.10/site-packages/joblib/memory.py:577: JobLibCollisionWarning: Cannot detect name collisions for function 'nifti_masker_extractor'
#   return self._cached_call(args, kwargs, shelving=False)[0]
# (198,)
# Working on Frontal_Inf_Orb_2_L
# (198,)
# Working on Frontal_Inf_Tri_L
# (198,)
# Working on Frontal_Mid_2_L
# (198,)
# Working on Temporal_Pole_Sup_L
# (198,)
# Working on Temporal_Mid_L
# (198,)
# done concatenating images
# (46, 56, 48, 153)
# Working on Angular_L
# /home/lyh/anaconda3/envs/llm4brain/lib/python3.10/site-packages/joblib/memory.py:577: JobLibCollisionWarning: Cannot detect name collisions for function 'nifti_masker_extractor'
#   return self._cached_call(args, kwargs, shelving=False)[0]
# (153,)
# Working on Frontal_Inf_Orb_2_L
# (153,)
# Working on Frontal_Inf_Tri_L
# (153,)
# Working on Frontal_Mid_2_L
# (153,)
# Working on Temporal_Pole_Sup_L
# (153,)
# Working on Temporal_Mid_L
# (153,)
# done concatenating images
# (46, 56, 48, 208)
# Working on Angular_L
# /home/lyh/anaconda3/envs/llm4brain/lib/python3.10/site-packages/joblib/memory.py:577: JobLibCollisionWarning: Cannot detect name collisions for function 'nifti_masker_extractor'
#   return self._cached_call(args, kwargs, shelving=False)[0]
# (208,)
# Working on Frontal_Inf_Orb_2_L
# (208,)
# Working on Frontal_Inf_Tri_L
# (208,)
# Working on Frontal_Mid_2_L
# (208,)
# Working on Temporal_Pole_Sup_L
# (208,)
# Working on Temporal_Mid_L
# (208,)
# done concatenating images
# (46, 56, 48, 143)
# Working on Angular_L
# /home/lyh/anaconda3/envs/llm4brain/lib/python3.10/site-packages/joblib/memory.py:577: JobLibCollisionWarning: Cannot detect name collisions for function 'nifti_masker_extractor'
#   return self._cached_call(args, kwargs, shelving=False)[0]
# (143,)
# Working on Frontal_Inf_Orb_2_L
# (143,)
# Working on Frontal_Inf_Tri_L
# (143,)
# Working on Frontal_Mid_2_L
# (143,)
# Working on Temporal_Pole_Sup_L
# (143,)
# Working on Temporal_Mid_L
# (143,)
# done concatenating images
# (46, 56, 48, 142)
# Working on Angular_L
# /home/lyh/anaconda3/envs/llm4brain/lib/python3.10/site-packages/joblib/memory.py:577: JobLibCollisionWarning: Cannot detect name collisions for function 'nifti_masker_extractor'
#   return self._cached_call(args, kwargs, shelving=False)[0]
# (142,)
# Working on Frontal_Inf_Orb_2_L
# (142,)
# Working on Frontal_Inf_Tri_L
# (142,)
# Working on Frontal_Mid_2_L
# (142,)
# Working on Temporal_Pole_Sup_L
# (142,)
# Working on Temporal_Mid_L
# (142,)
# done concatenating images
# (46, 56, 48, 199)
# Working on Angular_L
# /home/lyh/anaconda3/envs/llm4brain/lib/python3.10/site-packages/joblib/memory.py:577: JobLibCollisionWarning: Cannot detect name collisions for function 'nifti_masker_extractor'
#   return self._cached_call(args, kwargs, shelving=False)[0]
# (199,)
# Working on Frontal_Inf_Orb_2_L
# (199,)
# Working on Frontal_Inf_Tri_L
# (199,)
# Working on Frontal_Mid_2_L
# (199,)
# Working on Temporal_Pole_Sup_L
# (199,)
# Working on Temporal_Mid_L
# (199,)
# done concatenating images
# (46, 56, 48, 159)
# Working on Angular_L
# /home/lyh/anaconda3/envs/llm4brain/lib/python3.10/site-packages/joblib/memory.py:577: JobLibCollisionWarning: Cannot detect name collisions for function 'nifti_masker_extractor'
#   return self._cached_call(args, kwargs, shelving=False)[0]
# (159,)
# Working on Frontal_Inf_Orb_2_L
# (159,)
# Working on Frontal_Inf_Tri_L
# (159,)
# Working on Frontal_Mid_2_L
# (159,)
# Working on Temporal_Pole_Sup_L
# (159,)
# Working on Temporal_Mid_L
# (159,)
# done concatenating images
# (46, 56, 48, 167)
# Working on Angular_L
# /home/lyh/anaconda3/envs/llm4brain/lib/python3.10/site-packages/joblib/memory.py:577: JobLibCollisionWarning: Cannot detect name collisions for function 'nifti_masker_extractor'
#   return self._cached_call(args, kwargs, shelving=False)[0]
# (167,)
# Working on Frontal_Inf_Orb_2_L
# (167,)
# Working on Frontal_Inf_Tri_L
# (167,)
# Working on Frontal_Mid_2_L
# (167,)
# Working on Temporal_Pole_Sup_L
# (167,)
# Working on Temporal_Mid_L
# (167,)
# done concatenating images
# (46, 56, 48, 208)
# Working on Angular_L
# /home/lyh/anaconda3/envs/llm4brain/lib/python3.10/site-packages/joblib/memory.py:577: JobLibCollisionWarning: Cannot detect name collisions for function 'nifti_masker_extractor'
#   return self._cached_call(args, kwargs, shelving=False)[0]
# (208,)
# Working on Frontal_Inf_Orb_2_L
# (208,)
# Working on Frontal_Inf_Tri_L
# (208,)
# Working on Frontal_Mid_2_L
# (208,)
# Working on Temporal_Pole_Sup_L
# (208,)
# Working on Temporal_Mid_L
# (208,)
# done concatenating images
# (46, 56, 48, 198)
# Working on Angular_L
# /home/lyh/anaconda3/envs/llm4brain/lib/python3.10/site-packages/joblib/memory.py:577: JobLibCollisionWarning: Cannot detect name collisions for function 'nifti_masker_extractor'
#   return self._cached_call(args, kwargs, shelving=False)[0]
# (198,)
# Working on Frontal_Inf_Orb_2_L
# (198,)
# Working on Frontal_Inf_Tri_L
# (198,)
# Working on Frontal_Mid_2_L
# (198,)
# Working on Temporal_Pole_Sup_L
# (198,)
# Working on Temporal_Mid_L
# (198,)
# done concatenating images
# (46, 56, 48, 153)
# Working on Angular_L
# /home/lyh/anaconda3/envs/llm4brain/lib/python3.10/site-packages/joblib/memory.py:577: JobLibCollisionWarning: Cannot detect name collisions for function 'nifti_masker_extractor'
#   return self._cached_call(args, kwargs, shelving=False)[0]
# (153,)
# Working on Frontal_Inf_Orb_2_L
# (153,)
# Working on Frontal_Inf_Tri_L
# (153,)
# Working on Frontal_Mid_2_L
# (153,)
# Working on Temporal_Pole_Sup_L
# (153,)
# Working on Temporal_Mid_L
# (153,)
# done concatenating images
# (46, 56, 48, 208)
# Working on Angular_L
# /home/lyh/anaconda3/envs/llm4brain/lib/python3.10/site-packages/joblib/memory.py:577: JobLibCollisionWarning: Cannot detect name collisions for function 'nifti_masker_extractor'
#   return self._cached_call(args, kwargs, shelving=False)[0]
# (208,)
# Working on Frontal_Inf_Orb_2_L
# (208,)
# Working on Frontal_Inf_Tri_L
# (208,)
# Working on Frontal_Mid_2_L
# (208,)
# Working on Temporal_Pole_Sup_L
# (208,)
# Working on Temporal_Mid_L
# (208,)
# done concatenating images
# (46, 56, 48, 143)
# Working on Angular_L
# /home/lyh/anaconda3/envs/llm4brain/lib/python3.10/site-packages/joblib/memory.py:577: JobLibCollisionWarning: Cannot detect name collisions for function 'nifti_masker_extractor'
#   return self._cached_call(args, kwargs, shelving=False)[0]
# (143,)
# Working on Frontal_Inf_Orb_2_L
# (143,)
# Working on Frontal_Inf_Tri_L
# (143,)
# Working on Frontal_Mid_2_L
# (143,)
# Working on Temporal_Pole_Sup_L
# (143,)
# Working on Temporal_Mid_L
# (143,)
# done concatenating images
# (46, 56, 48, 142)
# Working on Angular_L
# /home/lyh/anaconda3/envs/llm4brain/lib/python3.10/site-packages/joblib/memory.py:577: JobLibCollisionWarning: Cannot detect name collisions for function 'nifti_masker_extractor'
#   return self._cached_call(args, kwargs, shelving=False)[0]
# (142,)
# Working on Frontal_Inf_Orb_2_L
# (142,)
# Working on Frontal_Inf_Tri_L
# (142,)
# Working on Frontal_Mid_2_L
# (142,)
# Working on Temporal_Pole_Sup_L
# (142,)
# Working on Temporal_Mid_L
# (142,)
# done concatenating images
# (46, 56, 48, 199)
# Working on Angular_L
# /home/lyh/anaconda3/envs/llm4brain/lib/python3.10/site-packages/joblib/memory.py:577: JobLibCollisionWarning: Cannot detect name collisions for function 'nifti_masker_extractor'
#   return self._cached_call(args, kwargs, shelving=False)[0]
# (199,)
# Working on Frontal_Inf_Orb_2_L
# (199,)
# Working on Frontal_Inf_Tri_L
# (199,)
# Working on Frontal_Mid_2_L
# (199,)
# Working on Temporal_Pole_Sup_L
# (199,)
# Working on Temporal_Mid_L
# (199,)
# done concatenating images
# (46, 56, 48, 159)
# Working on Angular_L
# /home/lyh/anaconda3/envs/llm4brain/lib/python3.10/site-packages/joblib/memory.py:577: JobLibCollisionWarning: Cannot detect name collisions for function 'nifti_masker_extractor'
#   return self._cached_call(args, kwargs, shelving=False)[0]
# (159,)
# Working on Frontal_Inf_Orb_2_L
# (159,)
# Working on Frontal_Inf_Tri_L
# (159,)
# Working on Frontal_Mid_2_L
# (159,)
# Working on Temporal_Pole_Sup_L
# (159,)
# Working on Temporal_Mid_L
# (159,)
# done concatenating images
# (46, 56, 48, 167)
# Working on Angular_L
# /home/lyh/anaconda3/envs/llm4brain/lib/python3.10/site-packages/joblib/memory.py:577: JobLibCollisionWarning: Cannot detect name collisions for function 'nifti_masker_extractor'
#   return self._cached_call(args, kwargs, shelving=False)[0]
# (167,)
# Working on Frontal_Inf_Orb_2_L
# (167,)
# Working on Frontal_Inf_Tri_L
# (167,)
# Working on Frontal_Mid_2_L
# (167,)
# Working on Temporal_Pole_Sup_L
# (167,)
# Working on Temporal_Mid_L
# (167,)
# done concatenating images
# (46, 56, 48, 208)
# Working on Angular_L
# /home/lyh/anaconda3/envs/llm4brain/lib/python3.10/site-packages/joblib/memory.py:577: JobLibCollisionWarning: Cannot detect name collisions for function 'nifti_masker_extractor'
#   return self._cached_call(args, kwargs, shelving=False)[0]
# (208,)
# Working on Frontal_Inf_Orb_2_L
# (208,)
# Working on Frontal_Inf_Tri_L
# (208,)
# Working on Frontal_Mid_2_L
# (208,)
# Working on Temporal_Pole_Sup_L
# (208,)
# Working on Temporal_Mid_L
# (208,)
# done concatenating images
# (46, 56, 48, 198)
# Working on Angular_L
# /home/lyh/anaconda3/envs/llm4brain/lib/python3.10/site-packages/joblib/memory.py:577: JobLibCollisionWarning: Cannot detect name collisions for function 'nifti_masker_extractor'
#   return self._cached_call(args, kwargs, shelving=False)[0]
# (198,)
# Working on Frontal_Inf_Orb_2_L
# (198,)
# Working on Frontal_Inf_Tri_L
# (198,)
# Working on Frontal_Mid_2_L
# (198,)
# Working on Temporal_Pole_Sup_L
# (198,)
# Working on Temporal_Mid_L
# (198,)
# done concatenating images
# (46, 56, 48, 153)
# Working on Angular_L
# /home/lyh/anaconda3/envs/llm4brain/lib/python3.10/site-packages/joblib/memory.py:577: JobLibCollisionWarning: Cannot detect name collisions for function 'nifti_masker_extractor'
#   return self._cached_call(args, kwargs, shelving=False)[0]
# (153,)
# Working on Frontal_Inf_Orb_2_L
# (153,)
# Working on Frontal_Inf_Tri_L
# (153,)
# Working on Frontal_Mid_2_L
# (153,)
# Working on Temporal_Pole_Sup_L
# (153,)
# Working on Temporal_Mid_L
# (153,)
# done concatenating images
# (46, 56, 48, 208)
# Working on Angular_L
# /home/lyh/anaconda3/envs/llm4brain/lib/python3.10/site-packages/joblib/memory.py:577: JobLibCollisionWarning: Cannot detect name collisions for function 'nifti_masker_extractor'
#   return self._cached_call(args, kwargs, shelving=False)[0]
# (208,)
# Working on Frontal_Inf_Orb_2_L
# (208,)
# Working on Frontal_Inf_Tri_L
# (208,)
# Working on Frontal_Mid_2_L
# (208,)
# Working on Temporal_Pole_Sup_L
# (208,)
# Working on Temporal_Mid_L
# (208,)
